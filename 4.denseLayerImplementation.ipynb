# %% [markdown]
# <h3>Generating non-linear datas</h3>

# %%
from nnfs.datasets import spiral_data
import numpy as np
import nnfs
nnfs.init()
import matplotlib.pyplot as plt
X,y = spiral_data(samples=100, classes=3)
plt.scatter(X[:,0], X[:,1], c=y, cmap="brg")
plt.show()

# %% [markdown]
# <h1>Dense Layer Class</h1>

# %%
class DenseLayer:
    def __init__(self, n_inputs, n_neurons):
        self.weights = 0.01 * np.random.randn(n_inputs, n_neurons)
        self.biases = np.zeros((1, n_neurons))
    
    def forward(self, inputs):
        self.output = np.dot(inputs, self.weights) + self.biases

# %%
X,y = spiral_data(samples=100, classes=3)
dense1 = DenseLayer(2,3)
dense1.forward(X)
print(dense1.output[:5])
# Out:
# [[ 0.0000000e+00  0.0000000e+00  0.0000000e+00]
#  [-1.3303231e-04 -3.1528922e-05  2.8821052e-05]
#  [-4.4189696e-04 -3.5378270e-04  2.7172439e-04]
#  [-6.2260416e-04 -5.6147587e-04  4.2737339e-04]
#  [-8.8992924e-04 -6.5534783e-04  5.0685176e-04]]
